# %%
# !pip install roboflow

# %%
import os

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov9c.pt')

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=your_api_key)
project = rf.workspace("mohamed-traore-2ekkp").project("taco-trash-annotations-in-context")
version = project.version(16)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Configura il settings.yaml

# %%
os.chdir("root/.config/Ultralytics")
# !cat settings.yaml
yaml_content = """
settings_version: 0.0.4
datasets_dir: /kaggle/working
weights_dir: weights
runs_dir: runs
uuid: 1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff
sync: true
api_key: ''
openai_api_key: ''
clearml: true
comet: true
dvc: true
hub: true
mlflow: true
neptune: true
raytune: true
tensorboard: true
wandb: true
"""

with open("settings.yaml", "w") as file:
    file.write(yaml_content)

# %%
## directory : TACO-TRASH ...
# !cat data.yaml
yaml_content = """
names:
- trash
nc: 1
roboflow:
  license: CC BY 4.0
  project: taco-trash-annotations-in-context
  url: https://universe.roboflow.com/mohamed-traore-2ekkp/taco-trash-annotations-in-context/dataset/16
  version: 16
  workspace: mohamed-traore-2ekkp
test: TACO:-Trash-Annotations-in-Context-Dataset-16/test/images
train: TACO:-Trash-Annotations-in-Context-Dataset-16/train/images
val: TACO:-Trash-Annotations-in-Context-Dataset-16/valid/images

"""

with open("data.yaml", "w") as file:
    file.write(yaml_content)

# %%
os.chdir("TACO:-Trash-Annotations-in-Context-Dataset-16")

# %% [markdown]
# ## TRAIN

# %%
results=model.train(data="data.yaml", epochs=100, imgsz="640", batch=16)
# Out:
# Ultralytics YOLOv8.2.44 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
os.getcwd()
# Out:
# '/kaggle/working'

# %%
model = YOLO("./TACO:-Trash-Annotations-in-Context-Dataset-16/runs/detect/train4/weights/best.pt")

# %%
os.chdir("TACO:-Trash-Annotations-in-Context-Dataset-16")

# %%
# !cat data.yaml
# Out:
# names:
# - trash
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: taco-trash-annotations-in-context
#   url: https://universe.roboflow.com/mohamed-traore-2ekkp/taco-trash-annotations-in-context/dataset/16
#   version: 16
#   workspace: mohamed-traore-2ekkp
# test: TACO:-Trash-Annotations-in-Context-Dataset-16/test/images
# train: TACO:-Trash-Annotations-in-Context-Dataset-16/train/images
# val: TACO:-Trash-Annotations-in-Context-Dataset-16/valid/images

# %% [markdown]
# ## EVALUATION ON TEST SET

# %%
metrics = model.val(data='data.yaml',conf=0.5,iou=0.7, imgsz=640, split='test')
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# val: Scanning /kaggle/working/datasets/TACO:-Trash-Annotations-in-Context-Dataset-16/test/labels... 151 images, 1 backgrounds, 0 corrupt: 100%|██████████| 151/151 [00:00<00:00, 875.28it/s]
# val: New cache created: /kaggle/working/datasets/TACO:-Trash-Annotations-in-Context-Dataset-16/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:08<00:00,  1.12it/s]
#                    all        151        569      0.752      0.315      0.542      0.452
# Speed: 1.7ms preprocess, 29.9ms inference, 0.0ms loss, 5.9ms postprocess per image
# Results saved to runs/detect/val3

# %% [markdown]
# ## Single prediction

# %%
source1 = "test/images/000044_jpg.rf.f54c8c4c8cf9d987a38451d657201394.jpg"
source2 = "test/images/000142_JPG.rf.846277276a1d88a8cbb26883fc1ea3cd.jpg"

# predict on an array of images
model.predict([source1, source2], save=True, imgsz=(1440, 1440 ), conf=0.5, augment=True, nms=True, iou=0.5)
# Out:
# 0: 1440x1440 2 trashs, 337.7ms
# 1: 1440x1440 1 trash, 337.7ms
# Speed: 25.5ms preprocess, 337.7ms inference, 127.9ms postprocess per image at shape (1, 3, 1440, 1440)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'trash'}
#  obb: None
#  orig_img: array([[[ 40,  53,  61],
#          [ 37,  50,  58],
#          [ 32,  48,  55],
#          ...,
#          [ 82, 112, 129],
#          [ 93, 123, 140],
#          [ 88, 118, 135]],
#
#         [[ 26,  42,  49],
#          [ 37,  53,  60],
#          [ 60,  76,  83],
#          ...,
#          [127, 157, 174],
#          [129, 159, 176],
#          [118, 148, 165]],
#
#         [[ 41,  59,  66],
#          [ 49,  67,  74],
#          [ 74,  92,  99],
#          ...,
#          [152, 182, 199],
#          [149, 179, 196],
#          [135, 165, 182]],
#
#         ...,
#
# ...
